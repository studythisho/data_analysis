# %% [markdown]
# <a href="https://colab.research.google.com/github/studythisho/data_analysis/blob/main/inclass/7%EB%8B%A8%EC%9B%90_4%EC%9B%94_8%EC%9D%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #07 데이터 정제 - 빠진 데이터, 이상한 데이터 제거하기
#
# ## 결측치 찾기

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'sex'   : ['M', 'F', np.nan, 'M', 'F'],
                   'score' : [5, 4, 3, 4, None]})
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df['score']
# Out:
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    NaN
# Name: score, dtype: float64

# %%
df['score'] + 1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# 4    NaN
# Name: score, dtype: float64

# %% [markdown]
# ### 결측치 확인하기 pd.isna()
#  isna를 쓰면 결측치가 들어 있는지 확인 가능

# %%
pd.isna(df)
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df.isna()
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
pd.isnull(df)
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df.isnull()
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df.isna().sum() # sum을 이용하여 결측치가 몇개 있는지 확인
# Out:
# sex      1
# score    1
# dtype: int64

# %%
df.isna().sum(axis = 1)
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# dtype: int64

# %%
pd.Series([True, False, True]).sum()
# Out:
# 2

# %%
df.isna().any()# 어떤 열이라도 누락된 값이 있으면
               # 해당 열에 대한 결과는 True가 되고, 그렇지 않으면 False
# Out:
# sex      True
# score    True
# dtype: bool

# %%
df.isna().all()
# Out:
# sex      False
# score    False
# dtype: bool

# %%
df.isna().any(axis = 1)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df.isna().all(axis = 1)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.notnull() # null이 아닐 경우 True null일 경우 False 반환
# Out:
#      sex  score
# 0   True   True
# 1   True   True
# 2  False   True
# 3   True   True
# 4   True  False

# %%
df.notnull().all()
# Out:
# sex      False
# score    False
# dtype: bool

# %%
df.notnull().all(axis=1)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
# 적어도 하나 이상 NaN인 행을 추출, 시험 예상
df[df.isna().any(axis=1)]
# Out:
#    sex  score
# 2  NaN    3.0
# 4    F    NaN

# %%
#NaN이 하나도 없는 행을 추출, 시험 예상
df[~df.isna().any(axis=1)]
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df[ [True]*5 ]
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df [ [True, True, False, False, True]]
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 4   F    NaN

# %% [markdown]
# ## 결측값 시각화
#
# *   패키지 missingno
#          데이터셋에서 누락된 값(missing values)을 시각화하고 이해하는 데 도움을 주는 Python 라이브러리

# %%
import seaborn as sns
sns.heatmap(df.isnull());

# %%
sns.heatmap(df.isnull(), cbar=False);

# %%
tdf = sns.load_dataset('titanic')
sns.heatmap(tdf.isnull(), cbar=False);

# %%
import missingno as msno
msno.matrix(tdf);

# %% [markdown]
# * 오른쪽의 스파크라인은 데이터 완성도의 일반적인 모양을 오약하고 데이터 세트에서 최대 및 최소 널링이 있는 행을 가리킵니다.
#   * 선의 왼쪽은 15개중 13개의 데이터가 있는 행
#   * 선의 오른쪽은 15개중 15개의 데이터가 있는 행

# %%
# 열 embarked이 NaN인 행 추출
tdf[ tdf.embarked.isna() ]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
tdf[(tdf.age.isna()) & (tdf.deck.isna()) ]
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 5           0       3    male  NaN      0      0   8.4583        Q   Third
# 17          1       2    male  NaN      0      0  13.0000        S  Second
# 19          1       3  female  NaN      0      0   7.2250        C   Third
# 26          0       3    male  NaN      0      0   7.2250        C   Third
# 28          1       3  female  NaN      0      0   7.8792        Q   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 859         0       3    male  NaN      0      0   7.2292        C   Third
# 863         0       3  female  NaN      8      2  69.5500        S   Third
# 868         0       3    male  NaN      0      0   9.5000        S   Third
# 878         0       3    male  NaN      0      0   7.8958        S   Third
# 888         0       3  female  NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 5      man        True  NaN   Queenstown    no   True
# 17     man        True  NaN  Southampton   yes   True
# 19   woman       False  NaN    Cherbourg   yes   True
# 26     man        True  NaN    Cherbourg    no   True
# 28   woman       False  NaN   Queenstown   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 859    man        True  NaN    Cherbourg    no   True
# 863  woman       False  NaN  Southampton    no  False
# 868    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
#
# [158 rows x 15 columns]

# %%
# 3 열이 모두 NaN인 행 추출
tdf[(tdf.age.isna()) & (tdf.deck.isna()) & (tdf.embark_town.isna()) ]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
# 최소한 1개의 NaN에 있는 행 추출
tdf[ tdf.isna().any(axis=1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 884    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
# 890    man        True  NaN   Queenstown    no   True
#
# [709 rows x 15 columns]

# %%
msno.bar(tdf);

# %% [markdown]
# ## 결측치 제거하기

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
# 열 score에 NaN이 제거
df.dropna()
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %% [markdown]
# * subset : 열 레이블 또는 레이블 시퀀스(선택 사항)
# * 예를 들어 행을 드롭하는 경우, 다른 축인 열을 지정하면 그열에 null이 있는 행을 제거

# %%
df.dropna(subset = ['score'])
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.dropna(axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# 행 2에 NaN이 있으면 열을 제거
df.dropna(subset=[2], axis = 1)
# Out:
#    score
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    NaN

# %%
df.dropna(subset=[4], axis = 1)
# Out:
#    sex
# 0    M
# 1    F
# 2  NaN
# 3    M
# 4    F

# %%
df.dropna(subset=[2, 4], axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# score, sex에서 결측값이 있는 행 제거
df_nomiss = df.dropna(subset = ['score', 'sex'])
df_nomiss
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df['score'].mean() # 결측값은 제거(무시) 하고 계산
# Out:
# 4.0

# %%
df['score'].sum() # 결측값은 제거(무시)하고 계산
# Out:
# 16.0

# %%
df.groupby('sex').agg(mean_score = ('score', 'mean'),
                      sum_score = ('score', 'sum'))
# Out:
#      mean_score  sum_score
# sex
# F           4.0        4.0
# M           4.5        9.0

# %% [markdown]
# ## pandas 문서

# %%
df = pd.DataFrame(dict(age=[5, 6, np.nan],
                       born=[pd.NaT, pd.Timestamp('1939-05-27'),
                             pd.Timestamp('1940-04-25')],
                       name=['Alfred', 'Batman', ''],
                       toy=[None, 'Batmobile', 'Joker']))
df
# Out:
#    age       born    name        toy
# 0  5.0        NaT  Alfred       None
# 1  6.0 1939-05-27  Batman  Batmobile
# 2  NaN 1940-04-25              Joker

# %%
df.isna()
# Out:
#      age   born   name    toy
# 0  False   True  False   True
# 1  False  False  False  False
# 2   True  False  False  False

# %%
ser = pd.Series([5, 6, np.nan])
ser
# Out:
# 0    5.0
# 1    6.0
# 2    NaN
# dtype: float64

# %%
ser.isna()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman', np.NaN],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip', np.nan],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT, pd.NaT]})
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
# 3       NaN        NaN        NaT

# %%
df.isna()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True
# 3   True   True   True

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(axis=1) # axis = 'columns'
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df.dropna(how = 'any')
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(how = 'all')
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %% [markdown]
# ## 결측치 대체하기
# 평균값으로 결측치 대체하기

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 4.00 MiB | 5.53 MiB/s, done.

# %%
exam = pd.read_csv('data/exam.csv')      # 데이터 불러오기
exam.loc[[2, 7, 14], ['math']] = np.nan  # 2, 7, 14행의 math에 NaN 할당
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
exam.loc[[2, 7, 14], ['math']]
# Out:
#     math
# 2    NaN
# 7    NaN
# 14   NaN

# %%
exam.loc[[2, 7, 14], 'math']
# Out:
# 2    NaN
# 7    NaN
# 14   NaN
# Name: math, dtype: float64

# %%
exam.math.mean()
# Out:
# 55.23529411764706

# %%
exam['math'] = exam['math'].fillna(100)  # math가 NaN이면 55로 대체
exam                                    # 출력
# Out:
#     id  nclass   math  english  science
# 0    1       1   50.0       98       50
# 1    2       1   60.0       97       60
# 2    3       1  100.0       86       78
# 3    4       1   30.0       98       58
# 4    5       2   25.0       80       65
# 5    6       2   50.0       89       98
# 6    7       2   80.0       90       45
# 7    8       2  100.0       78       25
# 8    9       3   20.0       98       15
# 9   10       3   50.0       98       45
# 10  11       3   65.0       65       65
# 11  12       3   45.0       85       32
# 12  13       4   46.0       98       65
# 13  14       4   48.0       87       12
# 14  15       4  100.0       56       78
# 15  16       4   58.0       98       65
# 16  17       5   65.0       68       98
# 17  18       5   80.0       78       90
# 18  19       5   89.0       68       87
# 19  20       5   78.0       83       58

# %%
exam = pd.read_csv('data/exam.csv')      # 데이터 불러오기
exam.loc[[2, 7, 14], ['math']] = np.nan  # 2, 7, 14행의 math에 NaN 할당
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
pd.set_option('display.precision', 3)

m = exam['math'].mean()
exam['math'] = exam['math'].fillna(m)  # math가 NaN이면 55로 대체
exam
# Out:
#     id  nclass    math  english  science
# 0    1       1  50.000       98       50
# 1    2       1  60.000       97       60
# 2    3       1  55.235       86       78
# 3    4       1  30.000       98       58
# 4    5       2  25.000       80       65
# 5    6       2  50.000       89       98
# 6    7       2  80.000       90       45
# 7    8       2  55.235       78       25
# 8    9       3  20.000       98       15
# 9   10       3  50.000       98       45
# 10  11       3  65.000       65       65
# 11  12       3  45.000       85       32
# 12  13       4  46.000       98       65
# 13  14       4  48.000       87       12
# 14  15       4  55.235       56       78
# 15  16       4  58.000       98       65
# 16  17       5  65.000       68       98
# 17  18       5  80.000       78       90
# 18  19       5  89.000       68       87
# 19  20       5  78.000       83       58

# %%
exam['math'].isna().sum()  # 결측치 빈도 확인
# Out:
# 0

# %% [markdown]
# 07-2 이상값 정제하기

# %%
df = pd.DataFrame({'sex'   : [1, 2, 1, 3, 2, 1],
                   'score' : [5, 4, 3, 4, 2, 6]})
df
# Out:
#    sex  score
# 0    1      5
# 1    2      4
# 2    1      3
# 3    3      4
# 4    2      2
# 5    1      6

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    3
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
df['sex'].value_counts().sort_values()
# Out:
# sex
# 3    1
# 2    2
# 1    3
# Name: count, dtype: int64

# %%
df['score'].value_counts()
# Out:
# score
# 4    2
# 5    1
# 3    1
# 2    1
# 6    1
# Name: count, dtype: int64

# %%
# sex가 3이면 NaN 부여
df['sex'] = np.where(df['sex'] == 3, np.nan, df['sex'])
df
# Out:
#    sex  score
# 0  1.0      5
# 1  2.0      4
# 2  1.0      3
# 3  NaN      4
# 4  2.0      2
# 5  1.0      6

# %%
# score가 5보다 크면 NaN 부여
df['score'] = np.where(df['score'] > 5, np.nan, df['score'])
df
# Out:
#    sex  score
# 0  1.0    5.0
# 1  2.0    4.0
# 2  1.0    3.0
# 3  NaN    4.0
# 4  2.0    2.0
# 5  1.0    NaN

# %%
df.dropna(subset = ['sex', 'score']).groupby('sex').agg(mean_score = ('score', 'mean'))
# Out:
#      mean_score
# sex
# 1.0         4.0
# 2.0         3.0

# %%
df.groupby('sex').agg(mean_score = ('score', 'mean'))
# Out:
#      mean_score
# sex
# 1.0         4.0
# 2.0         3.0

# %%
df = pd.DataFrame({'x1' : [1, 1, 2 ,2]})
df
# Out:
#    x1
# 0   1
# 1   1
# 2   2
# 3   2

# %%
df['x2'] = np.where(df['x1'] == 1, 10, np.nan) # 조건에 맞으면 문자 부여
df
# Out:
#    x1    x2
# 0   1  10.0
# 1   1  10.0
# 2   2   NaN
# 3   2   NaN

# %%
df.isna()
# Out:
#       x1     x2
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False   True

# %%
df['x2'] = np.where(df['x1'] == 1, 'a', 'etc')
df
# Out:
#    x1   x2
# 0   1    a
# 1   1    a
# 2   2  etc
# 3   2  etc

# %%
# 'etc'를 NaN으로 바꾸기
df['x2'] = df['x2'].replace('etc', np.nan)
df
# Out:
#    x1   x2
# 0   1    a
# 1   1    a
# 2   2  NaN
# 3   2  NaN

# %%
df.isna()
# Out:
#       x1     x2
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False   True

# %% [markdown]
# ## 이상치 제거하기 - 극단적인 값

# %%
import pandas as pd
mpg = pd.read_csv('data/mpg.csv')

# %%
mpg.sample(3)
# Out:
#     manufacturer        model  displ  year  cyl       trans drv  cty  hwy fl  \
# 15          audi   a6 quattro    2.8  1999    6    auto(l5)   4   15   24  p
# 173       toyota  4runner 4wd    2.7  1999    4  manual(m5)   4   15   20  r
# 113      hyundai       sonata    2.5  1999    6  manual(m5)   f   18   26  r
#
#     category
# 15   midsize
# 173      suv
# 113  midsize

# %%
import seaborn as sns
sns.boxplot(mpg, y = 'hwy');

# %%
s1 = pd.Series([1, 2, 3, 4 ,5])

# %%
s1.quantile(.50)
# Out:
# 3.0

# %%
s1.quantile([.25, .50, .75])
# Out:
# 0.25    2.0
# 0.50    3.0
# 0.75    4.0
# dtype: float64

# %%
s2 = pd.Series([1, 2, 4, 5])

# %%
s2.quantile(.50)
# Out:
# 3.0

# %%
s2.quantile([.25, .50, .75])
# Out:
# 0.25    1.75
# 0.50    3.00
# 0.75    4.25
# dtype: float64

# %%
pct25 = mpg['hwy'].quantile(.25)
pct25
# Out:
# 18.0

# %%
pct75 = mpg['hwy'].quantile(.75)
pct75
# Out:
# 27.0

# %%
iqr = pct75 - pct25
iqr
# Out:
# 9.0

# %%
pct25 - 1.5 * iqr  # 하한
# Out:
# 4.5

# %%
pct75 + 1.5 * iqr  # 상한
# Out:
# 40.5

# %%
mpg['hwy'].describe()
# Out:
# count    234.000
# mean      23.440
# std        5.955
# min       12.000
# 25%       18.000
# 50%       24.000
# 75%       27.000
# max       44.000
# Name: hwy, dtype: float64

# %%
mpg['hwy'].describe()['25%']
# Out:
# 18.0

# %%
dmpg = mpg.dropna(subset = ['hwy'])
len(dmpg)
# Out:
# 234

# %%
len(mpg)
# Out:
# 234

# %% [markdown]
# ## 3. 극단치를 결측 처리하기

# %%
import pandas as pd
mpg = pd.read_csv('data/mpg.csv')

# %%
# 4.5 ~ 40.5 벗어나면 NaN 부여
mpg['hwy'] = np.where((mpg['hwy'] < 4.5) | (mpg['hwy'] > 40.5), np.nan, mpg['hwy'])

# 결측치 빈도 확인
mpg['hwy'].isna().sum()
# Out:
# 3

# %%
mpg.dropna(subset = ['hwy']).groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4      19.175
# f      27.728
# r      21.000

# %%
mpg.groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4      19.175
# f      27.728
# r      21.000

# %% [markdown]
# # 정리하기

# %%
## 1. 결측치 정제하기
df = pd.DataFrame({'sex'   : [1, 2, 1, 3, 2, 1],
                   'score' : [5, 4, 3, 4, 2, 6]})
pd.isna(df).sum()                                 # 결측치 확인
df_nomiss = df.dropna(subset = ['score'])         # 결측치 제거
df_nomiss = df.dropna(subset = ['score', 'sex'])  # 여러 변수 동시에 결측치 제거


## 2. 이상치 정제하기

# 이상치 확인
df['sex'].value_counts(sort = False)

# 이상치 결측 처리
df['sex'] = np.where(df['sex'] == 3, np.nan, df['sex'])

# 상자 그림으로 극단치 기준값 찾기
pct25 = mpg['hwy'].quantile(.25)  # 1사분위수
pct75 = mpg['hwy'].quantile(.75)  # 3사분위수
iqr = pct75 - pct25               # IQR
pct25 - 1.5 * iqr                 # 하한
pct75 + 1.5 * iqr                 # 상한

# 극단치 결측 처리
mpg['hwy'] = np.where((mpg['hwy'] < 4.5) | (mpg['hwy'] > 40.5), np.nan, mpg['hwy'])
